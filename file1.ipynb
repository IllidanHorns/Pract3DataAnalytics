# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_set/railway.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31653 entries, 0 to 31652
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Transaction ID       31653 non-null  object
#  1   Date of Purchase     31653 non-null  object
#  2   Time of Purchase     31653 non-null  object
#  3   Purchase Type        31653 non-null  object
#  4   Payment Method       31653 non-null  object
#  5   Railcard             10735 non-null  object
#  6   Ticket Class         31653 non-null  object
#  7   Ticket Type          31653 non-null  object
#  8   Price                31653 non-null  int64
#  9   Departure Station    31653 non-null  object
#  10  Arrival Destination  31653 non-null  object
#  11  Date of Journey      31653 non-null  object
#  12  Departure Time       31653 non-null  object
#  13  Arrival Time         31653 non-null  object
#  14  Actual Arrival Time  29773 non-null  object
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
values = {'Railcard' : 'No information', 'Actual Arrival Time' : 'No information', 'Reason for Delay' : 'No information'}

# %%
df.fillna(value=values, inplace=True)

# %%
df
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 2      f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27
# 3      b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36
# 4      2be00b45-0762-485e-a7a3       2023-12-27         18:22:56
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 0            Online    Contactless           Adult     Standard     Advance
# ...

# %%
df.head(5)
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method        Railcard Ticket Class Ticket Type  Price  \
# 0    Contactless           Adult     Standard     Advance     43
# 1    Credit Card           Adult     Standard     Advance     23
# 2    Credit Card  No information     Standard     Advance      3
# 3    Credit Card  No information     Standard     Advance     13
# 4    Contactless  No information     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# ...

# %%
df.tail(5)
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 31648        Online    Credit Card  No information     Standard    Off-Peak
# 31649        Online    Contactless  No information     Standard    Off-Peak
# 31650       Station    Credit Card  No information     Standard    Off-Peak
# 31651       Station    Credit Card  No information     Standard    Off-Peak
# 31652       Station    Credit Card           Adult     Standard    Off-Peak
#
#        Price      Departure Station    Arrival Destination Date of Journey  \
# ...

# %%
df.loc[1:100]
# Out:
#               Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 1    b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2    f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3    b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4    2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
# 5    4e1dcd88-3d95-44ef-99fa       2023-12-30         07:56:06        Online
# ..                       ...              ...              ...           ...
# 96   bb416517-39a2-4db5-b9be       2024-01-02         01:22:25        Online
# 97   5579a244-2516-4511-8b57       2024-01-02         01:26:15        Online
# 98   2a2eb6c9-689e-473d-9e6c       2024-01-02         01:40:08        Online
# 99   7703c1a2-5115-436c-9bc6       2024-01-02         01:51:12       Station
# 100  97e4266f-7f58-4a5f-9969       2024-01-02         01:52:53       Station
#
# ...

# %%
df.iloc[1:100, 1:5]
# Out:
#    Date of Purchase Time of Purchase Purchase Type Payment Method
# 1        2023-12-16         11:23:01       Station    Credit Card
# 2        2023-12-19         19:51:27        Online    Credit Card
# 3        2023-12-20         23:00:36       Station    Credit Card
# 4        2023-12-27         18:22:56        Online    Contactless
# 5        2023-12-30         07:56:06        Online    Credit Card
# ..              ...              ...           ...            ...
# 95       2024-01-02         01:19:18        Online    Contactless
# 96       2024-01-02         01:22:25        Online    Credit Card
# 97       2024-01-02         01:26:15        Online    Contactless
# 98       2024-01-02         01:40:08        Online    Contactless
# 99       2024-01-02         01:51:12       Station    Credit Card
#
# [99 rows x 4 columns]

# %%
df.iloc[:100, 3:7].join(df.iloc[:, 8:11])
# Out:
#    Purchase Type Payment Method        Railcard Ticket Class  Price  \
# 0         Online    Contactless           Adult     Standard     43
# 1        Station    Credit Card           Adult     Standard     23
# 2         Online    Credit Card  No information     Standard      3
# 3        Station    Credit Card  No information     Standard     13
# 4         Online    Contactless  No information     Standard     76
# ..           ...            ...             ...          ...    ...
# 95        Online    Contactless        Disabled     Standard      5
# 96        Online    Credit Card  No information     Standard      5
# 97        Online    Contactless        Disabled     Standard      5
# 98        Online    Contactless           Adult  First Class      6
# 99       Station    Credit Card  No information     Standard      3
#
#         Departure Station    Arrival Destination
# 0       London Paddington  Liverpool Lime Street
# 1      London Kings Cross                   York
# ...

# %%
df.loc[100:200, 'Price':'Journey Status']
# Out:
#      Price      Departure Station    Arrival Destination Date of Journey  \
# 100     19      London Paddington                Reading      2024-01-02
# 101    200  Manchester Piccadilly          London Euston      2024-01-02
# 102      2  Liverpool Lime Street  Manchester Piccadilly      2024-01-03
# 103      5      London St Pancras  Birmingham New Street      2024-01-03
# 104     12      London St Pancras  Birmingham New Street      2024-01-02
# ..     ...                    ...                    ...             ...
# 196      9                Reading                Swindon      2024-01-03
# 197      3  Liverpool Lime Street  Manchester Piccadilly      2024-01-03
# 198      9                Reading                Swindon      2024-01-03
# 199      5  Liverpool Lime Street  Manchester Piccadilly      2024-01-02
# 200     35     London Kings Cross                   York      2024-01-03
#
#     Departure Time Arrival Time Actual Arrival Time Journey Status
# ...

# %%
result = df.drop(df.columns.difference(df.columns[3:7].tolist() + df.columns[8:11].tolist()), axis=1)
result
# Out:
#       Purchase Type Payment Method        Railcard Ticket Class  Price  \
# 0            Online    Contactless           Adult     Standard     43
# 1           Station    Credit Card           Adult     Standard     23
# 2            Online    Credit Card  No information     Standard      3
# 3           Station    Credit Card  No information     Standard     13
# 4            Online    Contactless  No information     Standard     76
# ...             ...            ...             ...          ...    ...
# 31648        Online    Credit Card  No information     Standard      4
# 31649        Online    Contactless  No information     Standard     10
# 31650       Station    Credit Card  No information     Standard      4
# 31651       Station    Credit Card  No information     Standard     10
# 31652       Station    Credit Card           Adult     Standard      3
#
#            Departure Station    Arrival Destination
# 0          London Paddington  Liverpool Lime Street
# ...

# %%
df.filter(items=['Purchase Type', 'Railcard'])
# Out:
#       Purchase Type        Railcard
# 0            Online           Adult
# 1           Station           Adult
# 2            Online  No information
# 3           Station  No information
# 4            Online  No information
# ...             ...             ...
# 31648        Online  No information
# 31649        Online  No information
# 31650       Station  No information
# 31651       Station  No information
# 31652       Station           Adult
#
# [31653 rows x 2 columns]

# %%
df[df['Price'] == 200]
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 101    c57dd321-4e2f-46c0-8cfb       2024-01-02         02:13:53
# 539    83a9482a-c116-4cb7-a588       2024-01-03         15:11:05
# 6177   4321c441-dfad-4050-b822       2024-01-24         02:04:49
# 7097   d123e5b0-26fa-4449-aef5       2024-01-27         06:42:48
# 8077   204b190d-1d19-4e6a-b409       2024-01-31         02:05:07
# 14057  a793b8bf-77c2-44d6-a19c       2024-02-16         02:14:21
# 28894  4f0f5ac2-9765-48e4-a083       2024-04-20         06:32:09
# 31404  fff63592-7176-4266-87d3       2024-04-29         15:00:34
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 101         Station    Credit Card  No information  First Class    Off-Peak
# 539         Station     Debit Card  No information  First Class    Off-Peak
# 6177        Station    Credit Card  No information  First Class    Off-Peak
# ...

# %%
df.query('Railcard == "Adult"')
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
# 1      b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01
# 6      1c74479d-85a4-4ba1-a607       2023-12-31         00:02:01
# 11     6c63f7ac-d590-4356-9eaa       2023-12-31         03:52:11
# 20     8dfbf0fc-aea0-424f-b30e       2023-12-31         11:57:15
# ...                        ...              ...              ...
# 31637  5dd5c27f-fd92-42c5-95f9       2024-04-30         17:05:54
# 31638  471bf3a2-aef7-4165-b493       2024-04-30         17:10:04
# 31640  753b9f3f-15cd-42be-8af0       2024-04-30         17:14:20
# 31641  2e96cde6-50c1-4311-8089       2024-04-30         17:16:04
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0            Online    Contactless    Adult     Standard     Advance     43
# ...

# %%
df.sort_values(by='Price')
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 21287  4e0d5a64-7c36-45d0-a686       2024-03-21         20:16:38
# 20713  7bf9d2e5-edbb-4c94-862c       2024-03-19         20:24:40
# 2488   39195f02-ae74-4902-bffd       2024-01-10         20:29:46
# 17221  dc4a283a-e411-402c-8d0c       2024-03-06         20:28:53
# 24481  93f73d08-d54f-4a29-9af0       2024-04-03         20:21:06
# ...                        ...              ...              ...
# 13367  d327e0ec-e1ac-436a-aa5c       2024-02-13         16:51:59
# 31434  a4bbac34-6ed7-4d71-b738       2024-04-29         16:49:20
# 711    092e5598-08de-42f5-b6b2       2024-01-04         06:35:01
# 2042   05193f47-2107-4bb8-8adb       2024-01-09         06:33:37
# 11849  de723682-3979-4d69-9664       2024-02-09         06:30:59
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 21287        Online    Credit Card  No information     Standard     Advance
# ...

# %%
df[df['Departure Station'].str.contains('Manchester', case=False)]
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 12     2e7add75-566a-41aa-9468       2023-12-31         05:55:22
# 13     7ed9b545-eb6f-49b2-9b5a       2023-12-31         06:44:35
# 25     842da93c-b820-42dc-ad4f       2023-12-31         15:19:53
# 35     ea7108cf-382b-4794-aa8c       2024-01-01         01:16:20
# 40     5f7dd36c-6a06-49bc-9ff6       2024-01-01         04:09:42
# ...                        ...              ...              ...
# 31634  8238d80b-e3b1-4448-8447       2024-04-30         16:11:33
# 31642  09e207d9-db49-4ec0-9c4f       2024-04-30         17:21:14
# 31645  a0e238b7-1ad1-4bf7-bd6c       2024-04-30         18:11:50
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 12           Online    Contactless  No information     Standard     Advance
# ...

# %%
df[df['Date of Purchase'].str.startswith('2024')]
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 34     a3a42b1b-bf7f-43d9-b63c       2024-01-01         01:10:20
# 35     ea7108cf-382b-4794-aa8c       2024-01-01         01:16:20
# 36     d8275e2a-8493-4b30-b6e0       2024-01-01         03:02:34
# 37     b7cf7da5-b4c2-4e24-897c       2024-01-01         03:03:49
# 38     58a7ad60-8670-41a4-87ba       2024-01-01         03:35:48
# ...                        ...              ...              ...
# 31648  1304623d-b8b7-4999-8e9c       2024-04-30         18:42:58
# 31649  7da22246-f480-417c-bc2f       2024-04-30         18:46:10
# 31650  add9debf-46c1-4c75-b52d       2024-04-30         18:56:41
# 31651  b92b047c-21fd-4859-966a       2024-04-30         19:51:47
# 31652  1d5d89a2-bde5-410f-8f91       2024-04-30         20:05:39
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 34          Station    Contactless  No information     Standard    Off-Peak
# ...

# %%
df[df['Price'].between(100, 150)]
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 45     767314a0-f839-4607-a3d3       2024-01-01         05:09:30
# 61     711c08ba-eb61-44ba-821a       2024-01-01         09:30:09
# 129    45843d84-051f-4f20-8129       2024-01-02         05:06:12
# 133    f59d227c-75ef-40d7-b3d0       2024-01-02         05:10:28
# 152    e149328e-6ed5-4d7c-ab84       2024-01-02         06:35:02
# ...                        ...              ...              ...
# 31542  cf61ca04-75e2-468f-ac38       2024-04-30         02:01:43
# 31557  745c7846-349a-4361-92b5       2024-04-30         05:06:22
# 31563  9c18f421-31ae-4529-ba33       2024-04-30         05:49:44
# 31637  5dd5c27f-fd92-42c5-95f9       2024-04-30         17:05:54
# 31639  465e3643-fb67-4deb-8ec9       2024-04-30         17:13:32
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 45          Station    Credit Card  No information  First Class     Advance
# ...

# %%
result = df.nlargest(5, 'Price')
result
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 711    092e5598-08de-42f5-b6b2       2024-01-04         06:35:01
# 2042   05193f47-2107-4bb8-8adb       2024-01-09         06:33:37
# 11849  de723682-3979-4d69-9664       2024-02-09         06:30:59
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 711         Station    Credit Card  No information  First Class     Anytime
# 2042        Station    Credit Card  No information  First Class     Anytime
# 11849       Station    Credit Card  No information  First Class     Anytime
#
#        Price      Departure Station Arrival Destination Date of Journey  \
# 711      267  Manchester Piccadilly       London Euston      2024-01-04
# 2042     267  Manchester Piccadilly       London Euston      2024-01-09
# 11849    267  Manchester Piccadilly       London Euston      2024-02-09
#
#       Departure Time Arrival Time Actual Arrival Time Journey Status  \
# ...

# %%
result = df.nsmallest(5, 'Price')
result
# Out:
#                Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 2488  39195f02-ae74-4902-bffd       2024-01-10         20:29:46        Online
# 3855  e633318f-b30d-4e0a-9cbd       2024-01-15         20:19:15        Online
# 7286  5e651fd0-c290-4b81-974b       2024-01-27         20:16:46        Online
#
#      Payment Method        Railcard Ticket Class Ticket Type  Price  \
# 2488    Credit Card  No information     Standard     Advance      1
# 3855    Credit Card  No information     Standard     Advance      1
# 7286    Credit Card  No information     Standard     Advance      1
#
#           Departure Station Arrival Destination Date of Journey  \
# 2488  Birmingham New Street       Wolverhampton      2024-01-11
# 3855  Birmingham New Street       Wolverhampton      2024-01-16
# 7286  Birmingham New Street       Wolverhampton      2024-01-28
#
#      Departure Time Arrival Time Actual Arrival Time Journey Status  \
# ...

# %%
df.sort_values(by='Purchase Type', ascending=False)
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 15826  a69e4d23-f5b3-4b55-8a8a       2024-03-01         12:44:00
# 16787  d9f8f92a-9d39-4d5d-9dfa       2024-03-05         09:25:44
# 16903  2c208ef5-d5cb-4d8a-9a21       2024-03-05         18:37:40
# 16902  4630a32a-882e-465d-aca7       2024-03-05         18:34:27
# 16898  00f6692a-b0ab-4a27-b344       2024-03-05         18:01:19
# ...                        ...              ...              ...
# 17402  711b8155-4551-4be7-bce5       2024-03-07         14:59:42
# 5966   515c6531-e388-41d1-8613       2024-01-23         08:03:32
# 5967   4b694b95-0343-45d8-bc1a       2024-01-23         08:05:56
# 17399  fa66652b-92c1-459a-8aec       2024-03-07         14:52:42
# 0      da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 15826       Station    Contactless  No information     Standard     Advance
# ...

# %%
df['Ticket Class'].unique()
# Out:
# array(['Standard', 'First Class'], dtype=object)

# %%
average_price = df.groupby('Ticket Class')['Price'].mean()
average_price
# Out:
# Ticket Class
# First Class    48.855134
# Standard       20.721175
# Name: Price, dtype: float64

# %%
result = df.groupby('Ticket Class').agg(
    count=('Price', 'count'),  
    avg_price=('Price', 'mean'),  
    total_price=('Price', 'sum')  
)

result
# Out:
#               count  avg_price  total_price
# Ticket Class
# First Class    3058  48.855134       149399
# Standard      28595  20.721175       592522

# %%
df.describe()
# Out:
#               Price                 departure_time  \
# count  31653.000000                          31653
# mean      23.439200  2024-11-14 12:01:51.856696064
# min        1.000000            2024-11-14 00:00:00
# 25%        5.000000            2024-11-14 07:00:00
# 50%       11.000000            2024-11-14 12:00:00
# 75%       35.000000            2024-11-14 17:45:00
# max      267.000000            2024-11-14 23:45:00
# std       29.997628                            NaN
#
#                         arrival_time
# count                          31653
# mean   2024-11-14 12:29:17.966069248
# min              2024-11-14 00:00:00
# 25%              2024-11-14 07:50:00
# 50%              2024-11-14 12:05:00
# 75%              2024-11-14 18:15:00
# max              2024-11-14 23:50:00
# std                              NaN

# %%
df['Departure Time'] = pd.to_datetime(df['Departure Time'])
df['Arrival Time'] = pd.to_datetime(df['Arrival Time'])
# Out:
# C:\Users\illid\AppData\Local\Temp\ipykernel_30572\2296692081.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Departure Time'] = pd.to_datetime(df['Departure Time'])
# C:\Users\illid\AppData\Local\Temp\ipykernel_30572\2296692081.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Arrival Time'] = pd.to_datetime(df['Arrival Time'])

# %%
df['Travel Duration'] = df['Departure Time'] - df['Arrival Time']

# %%
df.sort_values(by='Travel Duration', ascending=False).head(5)
# Out:
#                 Transaction ID Date of Purchase Time of Purchase  \
# 27456  559b4fcb-4185-4987-a1c4       2024-04-15         01:24:33
# 19184  bef0083b-1894-42d3-aa8a       2024-03-14         01:22:45
# 18903  f648d84f-a028-466c-a209       2024-03-13         01:18:31
# 1703   25a3f68f-e7c8-4a3a-82bc       2024-01-08         01:24:05
# 17501  7bd34905-1cc6-48c9-bd36       2024-03-08         01:17:23
#
#       Purchase Type Payment Method        Railcard Ticket Class Ticket Type  \
# 27456        Online    Contactless  No information     Standard    Off-Peak
# 19184        Online    Contactless  No information     Standard     Advance
# 18903        Online    Contactless  No information     Standard     Advance
# 1703         Online    Contactless  No information     Standard     Advance
# 17501        Online    Contactless  No information     Standard    Off-Peak
#
#        Price Departure Station  ... Date of Journey      Departure Time  \
# ...
